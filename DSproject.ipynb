# %% [markdown]
# <a href="https://colab.research.google.com/github/divyatejaswi86/Datascience-projects/blob/main/DSproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title convert csv into df
import pandas as pd
df = pd.read_csv('Coffe_sales.csv')
df
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort       Date     Time
# 0           Mar            5          3   3/1/2024  15:50.5
# 1           Mar            5          3   3/1/2024  19:22.5
# 2           Mar            5          3   3/1/2024  20:18.1
# 3           Mar            5          3   3/1/2024  46:33.0
# 4           Mar            5          3   3/1/2024  48:14.6
# ...         ...          ...        ...        ...      ...
# 3542        Mar            7          3  3/23/2025  34:54.9
# 3543        Mar            7          3  3/23/2025  43:37.4
# 3544        Mar            7          3  3/23/2025  44:16.9
# 3545        Mar            7          3  3/23/2025  47:28.7
# 3546        Mar            7          3  3/23/2025  11:38.6
#
# [3547 rows x 11 columns]

# %%
# @title checking size of dataset
print("no.of rows is ",df.shape[0])
print("no.of columns is ",df.shape[1])
# Out:
# no.of rows is  3547
# no.of columns is  11

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3547 entries, 0 to 3546
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hour_of_day  3547 non-null   int64
#  1   cash_type    3547 non-null   object
#  2   money        3547 non-null   float64
#  3   coffee_name  3547 non-null   object
#  4   Time_of_Day  3547 non-null   object
#  5   Weekday      3547 non-null   object
#  6   Month_name   3547 non-null   object
#  7   Weekdaysort  3547 non-null   int64
#  8   Monthsort    3547 non-null   int64
#  9   Date         3547 non-null   object
#  10  Time         3547 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 304.9+ KB

# %%
df.size
# Out:
# 39017

# %%
df.describe()
# Out:
#        hour_of_day        money  Weekdaysort    Monthsort
# count  3547.000000  3547.000000  3547.000000  3547.000000
# mean     14.185791    31.645216     3.845785     6.453905
# std       4.234010     4.877754     1.971501     3.500754
# min       6.000000    18.120000     1.000000     1.000000
# 25%      10.000000    27.920000     2.000000     3.000000
# 50%      14.000000    32.820000     4.000000     7.000000
# 75%      18.000000    35.760000     6.000000    10.000000
# max      22.000000    38.700000     7.000000    12.000000

# %%
# @title checking for null values
df.isnull().sum()
# Out:
# hour_of_day    0
# cash_type      0
# money          0
# coffee_name    0
# Time_of_Day    0
# Weekday        0
# Month_name     0
# Weekdaysort    0
# Monthsort      0
# Date           0
# Time           0
# dtype: int64

# %%
# @title Q1 sales vary by time of day
pd.unique(df['Time_of_Day'])
df['Time_of_Day'].value_counts().reset_index()
# Out:
#   Time_of_Day  count
# 0   Afternoon   1205
# 1     Morning   1181
# 2       Night   1161

# %%
# @title Q2 coffee_name has the highest number of sales
pd.unique(df['coffee_name'])
df['coffee_name'].value_counts().reset_index()
# Out:
#            coffee_name  count
# 0  Americano with Milk    809
# 1                Latte    757
# 2            Americano    564
# 3           Cappuccino    486
# 4              Cortado    287
# 5        Hot Chocolate    276
# 6                Cocoa    239
# 7             Espresso    129

# %%
# @title Q3 peak sales hours of a day(hour_of_day)
peak_sal = df['hour_of_day'].max()
df[df['hour_of_day'] == peak_sal][['coffee_name','hour_of_day']]
# Out:
#               coffee_name  hour_of_day
# 408         Hot Chocolate           22
# 432             Americano           22
# 433                 Latte           22
# 434                 Latte           22
# 500   Americano with Milk           22
# ...                   ...          ...
# 2649                Latte           22
# 2754        Hot Chocolate           22
# 2755                Latte           22
# 2803  Americano with Milk           22
# 2804            Americano           22
#
# [113 rows x 2 columns]

# %%
# @title Q4 average sales amount(money)
df['money'].mean()
# Out:
# np.float64(31.64521567521849)

# %%
# @title Q5 the total sales per day
df.groupby(by = 'coffee_name')['Date'].sum().reset_index()
# Out:
#            coffee_name                                               Date
# 0            Americano  3/1/20243/2/20243/2/20243/2/20243/3/20243/6/20...
# 1  Americano with Milk  3/1/20243/1/20243/1/20243/1/20243/2/20243/2/20...
# 2           Cappuccino  3/6/20243/6/20243/8/20243/9/20243/9/20243/9/20...
# 3                Cocoa  3/1/20243/3/20243/5/20243/20/20243/23/20243/26...
# 4              Cortado  3/3/20243/3/20243/5/20243/6/20243/8/20243/9/20...
# 5             Espresso  3/4/20243/9/20243/10/20243/13/20243/13/20243/1...
# 6        Hot Chocolate  3/1/20243/1/20243/1/20243/3/20243/3/20243/5/20...
# 7                Latte  3/1/20243/1/20243/3/20243/4/20243/4/20243/5/20...

# %%
# @title Q6 total coffee sales transactions
df.groupby(by = 'coffee_name')['money'].sum().reset_index()
# Out:
#            coffee_name     money
# 0            Americano  14650.26
# 1  Americano with Milk  24751.12
# 2           Cappuccino  17439.14
# 3                Cocoa   8521.16
# 4              Cortado   7384.86
# 5             Espresso   2690.28
# 6        Hot Chocolate   9933.46
# 7                Latte  26875.30

# %%
# @title Q7 the maximum and minimum sale amount
highest_sal = df['money'].max()
df[df['money'] == highest_sal][['coffee_name','money']]
# Out:
#        coffee_name  money
# 0            Latte   38.7
# 1    Hot Chocolate   38.7
# 2    Hot Chocolate   38.7
# 4            Latte   38.7
# 6    Hot Chocolate   38.7
# ..             ...    ...
# 274  Hot Chocolate   38.7
# 275     Cappuccino   38.7
# 276          Cocoa   38.7
# 282  Hot Chocolate   38.7
# 283     Cappuccino   38.7
#
# [128 rows x 2 columns]

# %%
highest_sal = df['money'].min()
df[df['money'] == highest_sal][['coffee_name','money']]
# Out:
#      coffee_name  money
# 888     Espresso  18.12
# 935     Espresso  18.12
# 938     Espresso  18.12
# 952     Espresso  18.12
# 957     Espresso  18.12
# 974     Espresso  18.12
# 976     Espresso  18.12
# 984     Espresso  18.12
# 1006    Espresso  18.12
# 1015    Espresso  18.12
# 1067    Espresso  18.12
# 1104    Espresso  18.12
# 1111    Espresso  18.12
# 1148    Espresso  18.12
# 1158    Espresso  18.12
# 1182    Espresso  18.12
# 1199    Espresso  18.12
# 1206    Espresso  18.12
# 1211    Espresso  18.12
# 1212    Espresso  18.12
# 1240    Espresso  18.12
# 1281    Espresso  18.12
# 1282    Espresso  18.12
# 1312    Espresso  18.12
# 1378    Espresso  18.12
# 1381    Espresso  18.12
# 1382    Espresso  18.12
# 1393    Espresso  18.12
# 1394    Espresso  18.12
# 1398    Espresso  18.12
# 1401    Espresso  18.12
# 1423    Espresso  18.12
# 1448    Espresso  18.12
# 1468    Espresso  18.12
# 1492    Espresso  18.12
# 1601    Espresso  18.12

# %%
# @title Q8 month had the highest total coffee sales
highest_sal = df['Month_name'].max()
df[df['Month_name'] == highest_sal][['Month_name','money']]
# Out:
#      Month_name  money
# 1316        Sep  23.02
# 1317        Sep  32.82
# 1318        Sep  27.92
# 1319        Sep  23.02
# 1320        Sep  27.92
# ...         ...    ...
# 1655        Sep  25.96
# 1656        Sep  35.76
# 1657        Sep  30.86
# 1658        Sep  30.86
# 1659        Sep  30.86
#
# [344 rows x 2 columns]

# %%
# @title Q9 sales trends differ between weekdays and weekend
df.groupby(by = 'money')['Weekdaysort'].sum().reset_index()
# Out:
#     money  Weekdaysort
# 0   18.12          161
# 1   21.06          217
# 2   23.02          864
# 3   24.00           54
# 4   25.96         1769
# 5   27.92         1231
# 6   28.90          373
# 7   30.86         1439
# 8   32.82         1926
# 9   33.80          214
# 10  35.76         3799
# 11  37.72         1075
# 12  38.70          519

# %%
# @title Q10 time of day  has the highest total sales
df.groupby(by = 'Time_of_Day')['money'].sum().reset_index()
# Out:
#   Time_of_Day     money
# 0   Afternoon  38130.04
# 1     Morning  35929.20
# 2       Night  38186.34

# %%
# @title Q11 the average transaction value during each time of day
df.groupby('Time_of_Day')['money'].mean().reset_index()
# Out:
#   Time_of_Day      money
# 0   Afternoon  31.643187
# 1     Morning  30.422693
# 2       Night  32.890904

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(data=df, x='Time_of_Day', y='money', estimator='mean', ci=None)
plt.title('Average Transaction Value by Time of Day')
plt.ylabel('Average Transaction Value')
plt.xlabel('Time of Day')
plt.show()
# Out:
# /tmp/ipython-input-1467481375.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x='Time_of_Day', y='money', estimator='mean', ci=None)

# %%
# @title Q12 trend in sales growth across months
df.groupby('Monthsort')['money'].mean().reset_index()
# Out:
#     Monthsort      money
# 0           1  31.835124
# 1           2  31.242270
# 2           3  32.169312
# 3           4  34.045000
# 4           5  33.877261
# 5           6  34.160359
# 6           7  29.181181
# 7           8  27.992059
# 8           9  29.036744
# 9          10  32.608357
# 10         11  33.168108
# 11         12  31.805946

# %%
# @title Q13  which coffee name is sold most
df['coffee_name'].value_counts()
# Out:
#    Month_name          coffee_name  count
# 0         Apr            Americano     33
# 1         Apr  Americano with Milk     38
# 2         Apr           Cappuccino     36
# 3         Apr                Cocoa      4
# 4         Apr              Cortado     16
# ..        ...                  ...    ...
# 91        Sep                Cocoa      9
# 92        Sep              Cortado     41
# 93        Sep             Espresso     12
# 94        Sep        Hot Chocolate     11
# 95        Sep                Latte     94
#
# [96 rows x 3 columns]

# %%
# @title Q15 Which coffee type generates the highest revenue overall
'''Solution:
Group by coffee_name, sum money, then sort.
'''
df.groupby("coffee_name")["money"].sum().sort_values(ascending=False)
# Out:
# coffee_name
# Latte                  26875.30
# Americano with Milk    24751.12
# Cappuccino             17439.14
# Americano              14650.26
# Hot Chocolate           9933.46
# Cocoa                   8521.16
# Cortado                 7384.86
# Espresso                2690.28
# Name: money, dtype: float64

# %%
# @title Q16 What is the hourly demand pattern (peak hours for sales)
'''Solution:
Group by hour_of_day, count transactions.
'''
df.groupby("hour_of_day")["money"].count()
# Out:
# hour_of_day
# 6       5
# 7      88
# 8     235
# 9     242
# 10    328
# 11    283
# 12    241
# 13    225
# 14    225
# 15    236
# 16    278
# 17    237
# 18    218
# 19    229
# 20    169
# 21    195
# 22    113
# Name: money, dtype: int64

# %%
# @title Q17 Is there a relationship between time-of-day and preferred coffee type
'''
Solution:
Create a cross-tab.
'''
pd.crosstab(df["Time_of_Day"], df["coffee_name"])
# Out:
# coffee_name  Americano  Americano with Milk  Cappuccino  Cocoa  Cortado  \
# Time_of_Day
# Afternoon          233                  239         164     75       88
# Morning            219                  331         122     58      143
# Night              112                  239         200    106       56
#
# coffee_name  Espresso  Hot Chocolate  Latte
# Time_of_Day
# Afternoon          56             80    270
# Morning            44             49    215
# Night              29            147    272

# %%
# @title Q18 Does payment method (cash/card) affect average spending
'''
Solution:
Compare mean spend of card vs cash
'''
df.groupby("cash_type")["money"].mean()
# Out:
# cash_type
# card    31.645216
# Name: money, dtype: float64

# %%
# @title Q19 How do weekday sales differ from weekend sales
'''
solution:
Group by Weekday.
'''
df.groupby("Weekday")["money"].sum()
# Out:
# Weekday
# Fri    16802.66
# Mon    17363.10
# Sat    14733.52
# Sun    13336.06
# Thu    16091.40
# Tue    18168.38
# Wed    15750.46
# Name: money, dtype: float64

# %%
# @title Q20 Which month had the maximum revenue
'''
solution:
Use Month_name.
'''
df.groupby("Month_name")["money"].sum().sort_values(ascending=False)
# Out:
# Month_name
# Mar    15891.64
# Oct    13891.16
# Feb    13215.48
# Sep     9988.64
# Nov     8590.54
# Dec     8237.74
# May     8164.42
# Jun     7617.76
# Aug     7613.84
# Jul     6915.94
# Jan     6398.86
# Apr     5719.56
# Name: money, dtype: float64

# %%
# @title Q21 Which coffee type has the highest average selling price
df.groupby("coffee_name")["money"].mean().sort_values(ascending=False)
# Out:
# coffee_name
# Hot Chocolate          35.990797
# Cappuccino             35.883004
# Cocoa                  35.653389
# Latte                  35.502378
# Americano with Milk    30.594710
# Americano              25.975638
# Cortado                25.731220
# Espresso               20.854884
# Name: money, dtype: float64

# %%
# @title Q22 Which combinations of attributes predict higher sales? (Multivariate)
df.groupby(["coffee_name", "Time_of_Day", "cash_type"])["money"].mean()
# Out:
# coffee_name          Time_of_Day  cash_type
# Americano            Afternoon    card         26.325923
#                      Morning      card         25.767580
#                      Night        card         25.653750
# Americano with Milk  Afternoon    card         30.896904
#                      Morning      card         30.288580
#                      Night        card         30.716485
# Cappuccino           Afternoon    card         36.040854
#                      Morning      card         35.470820
#                      Night        card         36.005000
# Cocoa                Afternoon    card         35.812267
#                      Morning      card         35.506552
#                      Night        card         35.621321
# Cortado              Afternoon    card         26.316364
#                      Morning      card         25.213007
#                      Night        card         26.135000
# Espresso             Afternoon    card         21.235000
#                      Morning      card         19.857273
#                      Night        card         21.634483
# Hot Chocolate        Afternoon    card         36.237750
#                      Morning      card         35.600000
#                      Night        card         35.986667
# Latte                Afternoon    card         35.596667
#                      Morning      card         35.582233
#                      Night        card         35.345662
# Name: money, dtype: float64

# %%
# @title Q23 Are morning customers more likely to buy expensive drinks
df.groupby("Time_of_Day")["money"].mean()
# Out:
# Time_of_Day
# Afternoon    31.643187
# Morning      30.422693
# Night        32.890904
# Name: money, dtype: float64
